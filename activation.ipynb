# %% [markdown]
# <a href="https://colab.research.google.com/github/ikeasamoahansah/Grokking-Deep-Learning/blob/main/activation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np, sys
np.random.seed(1)

from keras.datasets import mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
images, labels = (x_train[0:1000].reshape(1000, 28*28) \
                  /255, y_train[0:1000])

one_hot_labels = np.zeros((len(labels), 10))
for i, l in enumerate(labels):
  one_hot_labels[i][l] = 1
labels = one_hot_labels

test_images = x_test.reshape(len(x_test), 28*28) / 255
test_labels = np.zeros((len(y_test), 10))
for i, l in enumerate(y_test):
  test_labels[i][l] = 1

def tanh(x):
  return np.tanh(x)

def tanh2deriv(output):
  return 1-(output**2)

def softmax(x):
  temp = np.exp(x)
  return temp / np.sum(temp, axis=1, keepdims=True)

# %%
alpha, iterations, hidden_size = (2, 300, 100)
pixels_per_image, num_labels = (784, 10)
batch_size = 100

weights_0_1 = 0.2 * np.random.random((pixels_per_image, hidden_size))-0.1
weights_1_2 = 0.2 * np.random.random((hidden_size, num_labels))-0.1

for j in range(iterations):
  cnt = 0
  for i in range(int(len(images)/batch_size)):
    batch_start, batch_end = ((i*batch_size), ((i+1)*batch_size))
    layer_0 = images[batch_start:batch_end]
    layer_1 = tanh(np.dot(layer_0, weights_0_1))

    dropout_mask = np.random.randint(2, size=layer_1.shape)

    layer_1 *= dropout_mask * 2
    layer_2 = softmax(np.dot(layer_1, weights_1_2))

    for k in range(batch_size):
      cnt += int(np.argmax(layer_2[k:k+1]) == \
                 np.argmax(labels[batch_start+k: batch_start+k+1]))
      layer_2_delta = (labels[batch_start:batch_end]-layer_2) \
      / (batch_size * layer_2.shape[0])
      layer_1_delta = layer_2_delta.dot(weights_1_2.T) * tanh2deriv(layer_1)
      layer_1_delta *= dropout_mask

      weights_1_2 += alpha * layer_1.T.dot(layer_2_delta)
      weights_0_1 += alpha * layer_0.T.dot(layer_1_delta)
    test_cnt = 0

    for i in range(len(test_images)):
      layer_0 = test_images[i:i+1]
      layer_1 = tanh(np.dot(layer_0, weights_0_1))
      layer_2 = np.dot(layer_1, weights_1_2)
      test_cnt += int(np.argmax(layer_2) == \
                      np.argmax(test_labels[i:i+1]))
    # if (j % 100 == 0):
    sys.stdout.write("\n" + "I:" + str(j) + \
                      " Test-Acc:" +str(test_cnt/float(len(test_images))) + \
                      " Train-Acc:" + str(cnt/float(len(images))))
    print()
# Out:
# I:0 Test-Acc:0.3333 Train-Acc:0.011
#
# I:0 Test-Acc:0.4494 Train-Acc:0.04
#
# I:0 Test-Acc:0.4792 Train-Acc:0.079
#
# I:0 Test-Acc:0.378 Train-Acc:0.119
#
# I:0 Test-Acc:0.2258 Train-Acc:0.154
#
# I:0 Test-Acc:0.1202 Train-Acc:0.181
#
# I:0 Test-Acc:0.1135 Train-Acc:0.195
#
# I:0 Test-Acc:0.1135 Train-Acc:0.203
#
# I:0 Test-Acc:0.1135 Train-Acc:0.211
#
# I:0 Test-Acc:0.1135 Train-Acc:0.221
#
# I:1 Test-Acc:0.1135 Train-Acc:0.014
#
# I:1 Test-Acc:0.1388 Train-Acc:0.025
#
# I:1 Test-Acc:0.0957 Train-Acc:0.035
#
# I:1 Test-Acc:0.1032 Train-Acc:0.037
#
# I:1 Test-Acc:0.0711 Train-Acc:0.046
#
# I:1 Test-Acc:0.05 Train-Acc:0.053
#
# I:1 Test-Acc:0.0851 Train-Acc:0.06
#
# I:1 Test-Acc:0.0879 Train-Acc:0.066
#
# I:1 Test-Acc:0.028 Train-Acc:0.073
#
# I:1 Test-Acc:0.0077 Train-Acc:0.076
#
# I:2 Test-Acc:0.0326 Train-Acc:0.004
#
# I:2 Test-Acc:0.0735 Train-Acc:0.009
#
# I:2 Test-Acc:0.1039 Train-Acc:0.023
#
# I:2 Test-Acc:0.1312 Train-Acc:0.03
#
# I:2 Test-Acc:0.1711 Train-Acc:0.046
#
# I:2 Test-Acc:0.1616 Train-Acc:0.067
#
# I:2 Test-Acc:0.1842 Train-Acc:0.082
#
# I:2 Test-Acc:0.1376 Train-Acc:0.097
#
# I:2 Test-Acc:0.1179 Train-Acc:0.112
#
# I:2 Test-Acc:0.1576 Train-Acc:0.138
#
# I:3 Test-Acc:0.1561 Train-Acc:0.016
#
# I:3 Test-Acc:0.1369 Train-Acc:0.032
#
# I:3 Test-Acc:0.1715 Train-Acc:0.042
#
# I:3 Test-Acc:0.1191 Train-Acc:0.054
#
# I:3 Test-Acc:0.2117 Train-Acc:0.062
#
# I:3 Test-Acc:0.1286 Train-Acc:0.077
#
# I:3 Test-Acc:0.2261 Train-Acc:0.097
#
# I:3 Test-Acc:0.1227 Train-Acc:0.114
#
# I:3 Test-Acc:0.1779 Train-Acc:0.132
#
# I:3 Test-Acc:0.1301 Train-Acc:0.148
#
# I:4 Test-Acc:0.2116 Train-Acc:0.018
#
# I:4 Test-Acc:0.1902 Train-Acc:0.039
#
# I:4 Test-Acc:0.1594 Train-Acc:0.055
#
# I:4 Test-Acc:0.2336 Train-Acc:0.069
#
# I:4 Test-Acc:0.2629 Train-Acc:0.089
#
# I:4 Test-Acc:0.2045 Train-Acc:0.11
#
# I:4 Test-Acc:0.1618 Train-Acc:0.124
#
# I:4 Test-Acc:0.2461 Train-Acc:0.136
#
# I:4 Test-Acc:0.1877 Train-Acc:0.152
#
# I:4 Test-Acc:0.182 Train-Acc:0.167
#
# I:5 Test-Acc:0.2446 Train-Acc:0.016
#
# I:5 Test-Acc:0.1923 Train-Acc:0.039
#
# I:5 Test-Acc:0.2162 Train-Acc:0.061
#
# I:5 Test-Acc:0.2054 Train-Acc:0.081
#
# I:5 Test-Acc:0.1196 Train-Acc:0.1
#
# I:5 Test-Acc:0.2139 Train-Acc:0.109
#
# I:5 Test-Acc:0.1428 Train-Acc:0.129
#
# I:5 Test-Acc:0.1124 Train-Acc:0.142
#
# I:5 Test-Acc:0.1986 Train-Acc:0.156
#
# I:5 Test-Acc:0.0993 Train-Acc:0.17
#
# I:6 Test-Acc:0.133 Train-Acc:0.009
#
# I:6 Test-Acc:0.1792 Train-Acc:0.022
#
# I:6 Test-Acc:0.1539 Train-Acc:0.037
#
# I:6 Test-Acc:0.1963 Train-Acc:0.049
#
# I:6 Test-Acc:0.1411 Train-Acc:0.067
#
# I:6 Test-Acc:0.1497 Train-Acc:0.075
#
# I:6 Test-Acc:0.1943 Train-Acc:0.089
#
# I:6 Test-Acc:0.0945 Train-Acc:0.104
#
# I:6 Test-Acc:0.2072 Train-Acc:0.112
#
# I:6 Test-Acc:0.11 Train-Acc:0.132
#
# I:7 Test-Acc:0.1445 Train-Acc:0.01
#
# I:7 Test-Acc:0.1683 Train-Acc:0.02
#
# I:7 Test-Acc:0.1794 Train-Acc:0.034
#
# I:7 Test-Acc:0.1101 Train-Acc:0.054
#
# I:7 Test-Acc:0.186 Train-Acc:0.068
#
# I:7 Test-Acc:0.1616 Train-Acc:0.086
#
# I:7 Test-Acc:0.1407 Train-Acc:0.097
#
# I:7 Test-Acc:0.1004 Train-Acc:0.111
#
# I:7 Test-Acc:0.1131 Train-Acc:0.118
#
# I:7 Test-Acc:0.1542 Train-Acc:0.13
#
# I:8 Test-Acc:0.1526 Train-Acc:0.015
#
# I:8 Test-Acc:0.1056 Train-Acc:0.026
#
# I:8 Test-Acc:0.0954 Train-Acc:0.036
#
# I:8 Test-Acc:0.0889 Train-Acc:0.043
#
# I:8 Test-Acc:0.1106 Train-Acc:0.053
#
# I:8 Test-Acc:0.1309 Train-Acc:0.067
#
# I:8 Test-Acc:0.0766 Train-Acc:0.079
#
# I:8 Test-Acc:0.1259 Train-Acc:0.086
#
# I:8 Test-Acc:0.113 Train-Acc:0.094
#
# I:8 Test-Acc:0.082 Train-Acc:0.104
#
# I:9 Test-Acc:0.1138 Train-Acc:0.01
#
# I:9 Test-Acc:0.155 Train-Acc:0.022
#
# I:9 Test-Acc:0.1148 Train-Acc:0.039
#
# I:9 Test-Acc:0.151 Train-Acc:0.047
#
# I:9 Test-Acc:0.0954 Train-Acc:0.056
#
# I:9 Test-Acc:0.145 Train-Acc:0.065
#
# I:9 Test-Acc:0.1136 Train-Acc:0.075
#
# I:9 Test-Acc:0.0948 Train-Acc:0.084
#
# I:9 Test-Acc:0.1089 Train-Acc:0.089
#
# I:9 Test-Acc:0.1095 Train-Acc:0.111
#
# I:10 Test-Acc:0.122 Train-Acc:0.012
#
# I:10 Test-Acc:0.1051 Train-Acc:0.022
#
# I:10 Test-Acc:0.1842 Train-Acc:0.03
#
# I:10 Test-Acc:0.1062 Train-Acc:0.04
#
# I:10 Test-Acc:0.0997 Train-Acc:0.052
#
# I:10 Test-Acc:0.1724 Train-Acc:0.058
#
# I:10 Test-Acc:0.1037 Train-Acc:0.067
#
# I:10 Test-Acc:0.0988 Train-Acc:0.077
#
# I:10 Test-Acc:0.1469 Train-Acc:0.084
#
# I:10 Test-Acc:0.0942 Train-Acc:0.099
#
# I:11 Test-Acc:0.1775 Train-Acc:0.006
#
# I:11 Test-Acc:0.1131 Train-Acc:0.019
#
# I:11 Test-Acc:0.0962 Train-Acc:0.027
#
# I:11 Test-Acc:0.0915 Train-Acc:0.037
#
# I:11 Test-Acc:0.1322 Train-Acc:0.044
#
# I:11 Test-Acc:0.0893 Train-Acc:0.053
#
# I:11 Test-Acc:0.1425 Train-Acc:0.065
#
# I:11 Test-Acc:0.0896 Train-Acc:0.072
#
# I:11 Test-Acc:0.101 Train-Acc:0.077
#
# I:11 Test-Acc:0.1027 Train-Acc:0.084
#
# I:12 Test-Acc:0.1797 Train-Acc:0.008
#
# I:12 Test-Acc:0.1279 Train-Acc:0.023
#
# I:12 Test-Acc:0.0993 Train-Acc:0.031
#
# I:12 Test-Acc:0.1917 Train-Acc:0.039
#
# I:12 Test-Acc:0.0979 Train-Acc:0.055
#
# I:12 Test-Acc:0.0989 Train-Acc:0.064
#
# I:12 Test-Acc:0.1376 Train-Acc:0.079
#
# I:12 Test-Acc:0.0854 Train-Acc:0.089
#
# I:12 Test-Acc:0.1008 Train-Acc:0.098
#
# I:12 Test-Acc:0.1112 Train-Acc:0.109
#
# I:13 Test-Acc:0.0976 Train-Acc:0.009
#
# I:13 Test-Acc:0.1046 Train-Acc:0.018
#
# I:13 Test-Acc:0.1272 Train-Acc:0.027
#
# I:13 Test-Acc:0.0778 Train-Acc:0.037
#
# I:13 Test-Acc:0.0984 Train-Acc:0.044
#
# I:13 Test-Acc:0.1683 Train-Acc:0.049
#
# I:13 Test-Acc:0.0761 Train-Acc:0.063
#
# I:13 Test-Acc:0.0974 Train-Acc:0.068
#
# I:13 Test-Acc:0.0775 Train-Acc:0.075
#
# I:13 Test-Acc:0.0908 Train-Acc:0.083
#
# I:14 Test-Acc:0.0943 Train-Acc:0.011
#
# I:14 Test-Acc:0.0773 Train-Acc:0.019
#
# I:14 Test-Acc:0.0934 Train-Acc:0.028
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-f177f6eedb3d> in <cell line: 8>()
#      32     for i in range(len(test_images)):
#      33       layer_0 = test_images[i:i+1]
# ---> 34       layer_1 = tanh(np.dot(layer_0, weights_0_1))
#      35       layer_2 = np.dot(layer_1, weights_1_2)
#      36       test_cnt += int(np.argmax(layer_2) == \
#
# KeyboardInterrupt:
